# %%
import pandas as pd
import numpy as np
df = pd.read_csv("data/kc_house_data.csv")

# %%
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# 0          5650     1.0        NaN  NONE  ...      7 Average       1180
# 1          7242     2.0         NO  NONE  ...      7 Average       2170
# 2         10000     1.0         NO  NONE  ...  6 Low Average        770
# 3          5000     1.0         NO  NONE  ...      7 Average       1050
# 4          8080     1.0         NO  NONE  ...         8 Good       1680
# ...         ...     ...        ...   ...  ...            ...        ...
# 21592      1131     3.0         NO  NONE  ...         8 Good       1530
# 21593      5813     2.0         NO  NONE  ...         8 Good       2310
# 21594      1350     2.0         NO  NONE  ...      7 Average       1020
# 21595      2388     2.0        NaN  NONE  ...         8 Good       1600
# 21596      1076     2.0         NO  NONE  ...      7 Average       1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 0                0.0     1955           0.0    98178  47.5112 -122.257
# 1              400.0     1951        1991.0    98125  47.7210 -122.319
# 2                0.0     1933           NaN    98028  47.7379 -122.233
# 3              910.0     1965           0.0    98136  47.5208 -122.393
# 4                0.0     1987           0.0    98074  47.6168 -122.045
# ...              ...      ...           ...      ...      ...      ...
# 21592            0.0     2009           0.0    98103  47.6993 -122.346
# 21593            0.0     2014           0.0    98146  47.5107 -122.362
# 21594            0.0     2009           0.0    98144  47.5944 -122.299
# 21595            0.0     2004           0.0    98027  47.5345 -122.069
# 21596            0.0     2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [21597 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  object
#  9   view           21534 non-null  object
#  10  condition      21597 non-null  object
#  11  grade          21597 non-null  object
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(6), int64(9), object(6)
# memory usage: 3.5+ MB

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    sqft_above      yr_built  yr_renovated  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  17755.000000
# mean   1.509941e+04      1.494096   1788.596842   1970.999676     83.636778
# std    4.141264e+04      0.539683    827.759761     29.375234    399.946414
# min    5.200000e+02      1.000000    370.000000   1900.000000      0.000000
# 25%    5.040000e+03      1.000000   1190.000000   1951.000000      0.000000
# 50%    7.618000e+03      1.500000   1560.000000   1975.000000      0.000000
# 75%    1.068500e+04      2.000000   2210.000000   1997.000000      0.000000
# max    1.651359e+06      3.500000   9410.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21597.000000  21597.000000  21597.000000   21597.000000   21597.000000
# mean   98077.951845     47.560093   -122.213982    1986.620318   12758.283512
# std       53.513072      0.138552      0.140724     685.230472   27274.441950
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471100   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.231000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
df.dropna(subset=['view'], inplace = True)
df['date'] = pd.to_datetime(df['date'])

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2370
# view                0
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3830
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

ord_cat_selector = ['condition', 'grade', 'view']
cat_subset = df[ord_cat_selector]
cat_subset
# Out:
#        condition          grade  view
# 0        Average      7 Average  NONE
# 1        Average      7 Average  NONE
# 2        Average  6 Low Average  NONE
# 3      Very Good      7 Average  NONE
# 4        Average         8 Good  NONE
# ...          ...            ...   ...
# 21592    Average         8 Good  NONE
# 21593    Average         8 Good  NONE
# 21594    Average      7 Average  NONE
# 21595    Average         8 Good  NONE
# 21596    Average      7 Average  NONE
#
# [21534 rows x 3 columns]

# %%
print(cat_subset['condition'].unique())
print(cat_subset['grade'].unique())
print(cat_subset['view'].unique())
# Out:
# ['Average' 'Very Good' 'Good' 'Poor' 'Fair']
# ['7 Average' '6 Low Average' '8 Good' '11 Excellent' '9 Better' '5 Fair'
#  '10 Very Good' '12 Luxury' '4 Low' '3 Poor' '13 Mansion']
# ['NONE' 'GOOD' 'EXCELLENT' 'AVERAGE' 'FAIR']

# %%
condition_list = ['Poor', 'Fair', 'Average', 'Good', 'Very Good']
grade_list = ['3 Poor', '4 Low', '5 Fair', '6 Low Average', '7 Average', '8 Good',
              '9 Better', '10 Very Good', '11 Excellent', '12 Luxury', '13 Mansion']
view_list = ['NONE', 'FAIR', 'AVERAGE', 'GOOD', 'EXCELLENT']

# %%
o_enc = OrdinalEncoder(categories = [condition_list, grade_list, view_list])
o_enc.fit(cat_subset)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Fair', 'Average', 'Good', 'Very Good'],
#                            ['3 Poor', '4 Low', '5 Fair', '6 Low Average',
#                             '7 Average', '8 Good', '9 Better', '10 Very Good',
#                             '11 Excellent', '12 Luxury', '13 Mansion'],
#                            ['NONE', 'FAIR', 'AVERAGE', 'GOOD', 'EXCELLENT']])

# %%
X_subset = pd.DataFrame(o_enc.transform(cat_subset),
                        columns = cat_subset.columns)
X_subset
# Out:
#        condition  grade  view
# 0            2.0    4.0   0.0
# 1            2.0    4.0   0.0
# 2            2.0    3.0   0.0
# 3            4.0    4.0   0.0
# 4            2.0    5.0   0.0
# ...          ...    ...   ...
# 21529        2.0    5.0   0.0
# 21530        2.0    5.0   0.0
# 21531        2.0    4.0   0.0
# 21532        2.0    5.0   0.0
# 21533        2.0    4.0   0.0
#
# [21534 rows x 3 columns]

# %%
df['cond_num'] = X_subset['condition']
df['grade_num'] = X_subset['grade']
df['view_num'] = X_subset['view']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21534 entries, 0 to 21596
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21534 non-null  int64
#  1   date           21534 non-null  datetime64[ns]
#  2   price          21534 non-null  float64
#  3   bedrooms       21534 non-null  int64
#  4   bathrooms      21534 non-null  float64
#  5   sqft_living    21534 non-null  int64
#  6   sqft_lot       21534 non-null  int64
#  7   floors         21534 non-null  float64
#  8   waterfront     19164 non-null  object
#  9   view           21534 non-null  object
#  10  condition      21534 non-null  object
#  11  grade          21534 non-null  object
#  12  sqft_above     21534 non-null  int64
#  13  sqft_basement  21534 non-null  object
#  14  yr_built       21534 non-null  int64
#  15  yr_renovated   17704 non-null  float64
#  16  zipcode        21534 non-null  int64
#  17  lat            21534 non-null  float64
#  18  long           21534 non-null  float64
#  19  sqft_living15  21534 non-null  int64
#  20  sqft_lot15     21534 non-null  int64
#  21  cond_num       21472 non-null  float64
#  22  grade_num      21472 non-null  float64
#  23  view_num       21472 non-null  float64
# dtypes: datetime64[ns](1), float64(9), int64(9), object(5)
# memory usage: 4.1+ MB

# %%
df.dropna(subset=['view_num', 'cond_num', 'grade_num'], inplace = True)

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2359
# view                0
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3818
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# cond_num            0
# grade_num           0
# view_num            0
# dtype: int64

# %%
df['sqft_basement'].unique()
# Out:
# array(['0.0', '400.0', '910.0', '1530.0', '?', '730.0', '1700.0', '300.0',
#        '970.0', '760.0', '720.0', '700.0', '820.0', '780.0', '790.0',
#        '330.0', '1620.0', '360.0', '588.0', '1510.0', '410.0', '990.0',
#        '600.0', '560.0', '550.0', '1000.0', '1600.0', '500.0', '1040.0',
#        '880.0', '1010.0', '240.0', '265.0', '290.0', '800.0', '540.0',
#        '840.0', '380.0', '770.0', '480.0', '570.0', '1490.0', '620.0',
#        '1250.0', '1270.0', '120.0', '650.0', '180.0', '1130.0', '450.0',
#        '1640.0', '1460.0', '1020.0', '1030.0', '750.0', '640.0', '1070.0',
#        '490.0', '1310.0', '630.0', '2000.0', '390.0', '430.0', '210.0',
#        '1430.0', '1950.0', '440.0', '220.0', '1160.0', '860.0', '580.0',
#        '2060.0', '1820.0', '1180.0', '200.0', '1150.0', '1200.0', '680.0',
#        '530.0', '1450.0', '1170.0', '1080.0', '960.0', '280.0', '870.0',
#        '1100.0', '460.0', '1400.0', '660.0', '1220.0', '900.0', '420.0',
#        '1580.0', '1380.0', '475.0', '690.0', '270.0', '350.0', '935.0',
#        '710.0', '1370.0', '980.0', '850.0', '1470.0', '160.0', '950.0',
#        '50.0', '740.0', '1780.0', '1900.0', '340.0', '470.0', '370.0',
#        '140.0', '1760.0', '130.0', '520.0', '890.0', '1110.0', '150.0',
#        '1720.0', '810.0', '190.0', '1290.0', '670.0', '1800.0', '1120.0',
#        '1810.0', '60.0', '1050.0', '940.0', '310.0', '930.0', '1390.0',
#        '610.0', '1830.0', '1300.0', '510.0', '1330.0', '1590.0', '920.0',
#        '1320.0', '1420.0', '1240.0', '1960.0', '1560.0', '2020.0',
#        '1190.0', '2110.0', '1280.0', '250.0', '1230.0', '170.0', '830.0',
#        '1260.0', '1410.0', '1340.0', '590.0', '1500.0', '1140.0', '260.0',
#        '100.0', '320.0', '1480.0', '1060.0', '1284.0', '1670.0', '1350.0',
#        '2570.0', '1090.0', '110.0', '2500.0', '90.0', '1940.0', '1550.0',
#        '2350.0', '2490.0', '1481.0', '1360.0', '1135.0', '1520.0',
#        '1850.0', '1660.0', '2130.0', '2600.0', '1690.0', '243.0',
#        '1210.0', '1024.0', '1798.0', '1610.0', '1440.0', '1570.0',
#        '1650.0', '704.0', '1910.0', '1630.0', '2360.0', '1852.0',
#        '2090.0', '2400.0', '1790.0', '2150.0', '230.0', '70.0', '1680.0',
#        '2100.0', '3000.0', '1870.0', '1710.0', '2030.0', '875.0',
#        '1540.0', '2850.0', '2170.0', '506.0', '906.0', '145.0', '2040.0',
#        '784.0', '1750.0', '374.0', '518.0', '2720.0', '2730.0', '1840.0',
#        '3480.0', '2160.0', '1920.0', '2330.0', '1860.0', '2050.0',
#        '4820.0', '1913.0', '80.0', '2010.0', '3260.0', '2200.0', '415.0',
#        '1730.0', '652.0', '2196.0', '1930.0', '515.0', '40.0', '2080.0',
#        '2580.0', '1548.0', '1740.0', '235.0', '861.0', '1890.0', '2220.0',
#        '792.0', '2070.0', '4130.0', '2250.0', '2240.0', '1990.0', '768.0',
#        '2550.0', '435.0', '1008.0', '2300.0', '2610.0', '666.0', '3500.0',
#        '172.0', '1816.0', '2190.0', '1245.0', '1525.0', '1880.0', '862.0',
#        '946.0', '1281.0', '414.0', '276.0', '1248.0', '602.0', '516.0',
#        '176.0', '225.0', '1275.0', '266.0', '283.0', '65.0', '2310.0',
#        '10.0', '1770.0', '2120.0', '295.0', '207.0', '915.0', '556.0',
#        '417.0', '143.0', '508.0', '2810.0', '20.0', '274.0', '248.0'],
#       dtype=object)

# %%
df['sqft_basement'] =  df["sqft_basement"].replace("?", np.NaN)

# %%
df['sqft_basement'].isna().sum()
# Out:
# 451

# %%
df.dropna(subset = ["sqft_basement"], inplace = True)

# %%
df.shape
# Out:
# (21021, 24)

# %%
df['sqft_basement'] = df['sqft_basement'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21021 entries, 0 to 21533
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21021 non-null  int64
#  1   date           21021 non-null  datetime64[ns]
#  2   price          21021 non-null  float64
#  3   bedrooms       21021 non-null  int64
#  4   bathrooms      21021 non-null  float64
#  5   sqft_living    21021 non-null  int64
#  6   sqft_lot       21021 non-null  int64
#  7   floors         21021 non-null  float64
#  8   waterfront     18699 non-null  object
#  9   view           21021 non-null  object
#  10  condition      21021 non-null  object
#  11  grade          21021 non-null  object
#  12  sqft_above     21021 non-null  int64
#  13  sqft_basement  21021 non-null  float64
#  14  yr_built       21021 non-null  int64
#  15  yr_renovated   17290 non-null  float64
#  16  zipcode        21021 non-null  int64
#  17  lat            21021 non-null  float64
#  18  long           21021 non-null  float64
#  19  sqft_living15  21021 non-null  int64
#  20  sqft_lot15     21021 non-null  int64
#  21  cond_num       21021 non-null  float64
#  22  grade_num      21021 non-null  float64
#  23  view_num       21021 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int64(9), object(4)
# memory usage: 4.0+ MB

# %%
df['waterfront']
# Out:
# 0        NaN
# 1         NO
# 2         NO
# 3         NO
# 4         NO
#         ...
# 21529     NO
# 21530     NO
# 21531     NO
# 21532     NO
# 21533     NO
# Name: waterfront, Length: 21021, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (20,20))
sns.heatmap(df.corr().abs(), annot = True)
# Out:
# <AxesSubplot:>

# %%
#plt.figure(figsize = (20,20))
#sns.pairplot(df, corner = True)

# %% [markdown]
# Prelim findings:
#
# sqft_living = sqft_above + sqft_basement
#
# Price has the highest correlation with sqft_living
#
# This is followed by bathrooms which logically makes sense as if you have more than one bathroom you can afford enough space for it, thus is also related to sqft_living.

# %%
df_red = df.drop(['sqft_above', 'sqft_basement', 'lat', 'long'], axis=1)

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21021 entries, 0 to 21533
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21021 non-null  int64
#  1   date           21021 non-null  datetime64[ns]
#  2   price          21021 non-null  float64
#  3   bedrooms       21021 non-null  int64
#  4   bathrooms      21021 non-null  float64
#  5   sqft_living    21021 non-null  int64
#  6   sqft_lot       21021 non-null  int64
#  7   floors         21021 non-null  float64
#  8   waterfront     18699 non-null  object
#  9   view           21021 non-null  object
#  10  condition      21021 non-null  object
#  11  grade          21021 non-null  object
#  12  yr_built       21021 non-null  int64
#  13  yr_renovated   17290 non-null  float64
#  14  zipcode        21021 non-null  int64
#  15  sqft_living15  21021 non-null  int64
#  16  sqft_lot15     21021 non-null  int64
#  17  cond_num       21021 non-null  float64
#  18  grade_num      21021 non-null  float64
#  19  view_num       21021 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(8), object(4)
# memory usage: 3.4+ MB

# %%
plt.figure(figsize = (20,20))
sns.heatmap(df_red.corr().abs(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# It is very suprising that the price is hardly affected by the view, grade, or condition of the home.

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21021 entries, 0 to 21533
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21021 non-null  int64
#  1   date           21021 non-null  datetime64[ns]
#  2   price          21021 non-null  float64
#  3   bedrooms       21021 non-null  int64
#  4   bathrooms      21021 non-null  float64
#  5   sqft_living    21021 non-null  int64
#  6   sqft_lot       21021 non-null  int64
#  7   floors         21021 non-null  float64
#  8   waterfront     18699 non-null  object
#  9   view           21021 non-null  object
#  10  condition      21021 non-null  object
#  11  grade          21021 non-null  object
#  12  sqft_above     21021 non-null  int64
#  13  sqft_basement  21021 non-null  float64
#  14  yr_built       21021 non-null  int64
#  15  yr_renovated   17290 non-null  float64
#  16  zipcode        21021 non-null  int64
#  17  lat            21021 non-null  float64
#  18  long           21021 non-null  float64
#  19  sqft_living15  21021 non-null  int64
#  20  sqft_lot15     21021 non-null  int64
#  21  cond_num       21021 non-null  float64
#  22  grade_num      21021 non-null  float64
#  23  view_num       21021 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int64(9), object(4)
# memory usage: 4.0+ MB

# %%
df_red = df.drop(columns=['id','sqft_above', 'sqft_basement', 'lat', 'long', 'waterfront', 'view', 'condition', 'grade', 'date'])

# %%
df_red.dropna(subset = ['yr_renovated'], inplace = True)

# %%
X = df_red.drop(columns=['price'])
y = df_red['price']

model = sm.OLS(endog = y, exog=sm.add_constant(X)).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.574
# Model:                            OLS   Adj. R-squared:                  0.573
# Method:                 Least Squares   F-statistic:                     1788.
# Date:                Sun, 11 Sep 2022   Prob (F-statistic):               0.00
# Time:                        15:44:03   Log-Likelihood:            -2.3874e+05
# No. Observations:               17290   AIC:                         4.775e+05
# Df Residuals:                   17276   BIC:                         4.776e+05
# Df Model:                          13
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -1.335e+07   3.77e+06     -3.537      0.000   -2.07e+07   -5.95e+06
# bedrooms      -6.356e+04   2466.537    -25.767      0.000   -6.84e+04   -5.87e+04
# bathrooms      6.746e+04   4260.475     15.833      0.000    5.91e+04    7.58e+04
# sqft_living     252.4208      4.109     61.437      0.000     244.368     260.474
# sqft_lot         -0.0108      0.062     -0.174      0.862      -0.133       0.111
# floors         4.854e+04   4224.869     11.489      0.000    4.03e+04    5.68e+04
# yr_built      -3372.2075     85.557    -39.415      0.000   -3539.908   -3204.507
# yr_renovated     26.7230      4.807      5.559      0.000      17.300      36.146
# zipcode         202.0218     37.915      5.328      0.000     127.705     276.338
# sqft_living15    94.5091      4.212     22.438      0.000      86.253     102.765
# sqft_lot15       -0.6088      0.096     -6.332      0.000      -0.797      -0.420
# cond_num      -3380.5963   2864.630     -1.180      0.238   -8995.561    2234.369
# grade_num      4194.4566   1639.938      2.558      0.011     980.012    7408.901
# view_num       -260.4816   2483.533     -0.105      0.916   -5128.458    4607.495
# ==============================================================================
# Omnibus:                    12636.950   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           629703.677
# Skew:                           3.000   Prob(JB):                         0.00
# Kurtosis:                      31.950   Cond. No.                     2.08e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.08e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.figure(figsize = (20,20))
sns.heatmap(df_red.corr().abs(), annot = True)
# Out:
# <AxesSubplot:>

# %%
X = df_red['sqft_living']
y = df_red['price']

model_1 = sm.OLS(endog = y, exog=sm.add_constant(X)).fit()
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.495
# Model:                            OLS   Adj. R-squared:                  0.495
# Method:                 Least Squares   F-statistic:                 1.696e+04
# Date:                Sun, 11 Sep 2022   Prob (F-statistic):               0.00
# Time:                        16:00:20   Log-Likelihood:            -2.4020e+05
# No. Observations:               17290   AIC:                         4.804e+05
# Df Residuals:                   17288   BIC:                         4.804e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -4.797e+04   4935.968     -9.718      0.000   -5.76e+04   -3.83e+04
# sqft_living   282.2950      2.168    130.227      0.000     278.046     286.544
# ==============================================================================
# Omnibus:                    12071.453   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           481342.211
# Skew:                           2.868   Prob(JB):                         0.00
# Kurtosis:                      28.204   Cond. No.                     5.65e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df1 = df.iloc[:, 1:11]

# %%
df1
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13   221900.0         3       1.00         1180      5650
# 1     2014-12-09   538000.0         3       2.25         2570      7242
# 2     2015-02-25   180000.0         2       1.00          770     10000
# 3     2014-12-09   604000.0         4       3.00         1960      5000
# 4     2015-02-18   510000.0         3       2.00         1680      8080
# ...          ...        ...       ...        ...          ...       ...
# 21529 2014-12-15   405000.0         4       2.50         1980      5020
# 21530 2014-07-07   509900.0         3       2.50         3030      9053
# 21531 2014-08-20   327000.0         2       2.00         1490      1627
# 21532 2014-08-19  1060000.0         2       1.50         2370    184231
# 21533 2014-12-31   327500.0         3       2.50         1820      1866
#
#        floors waterfront  view  condition
# 0         1.0        NaN  NONE    Average
# 1         2.0         NO  NONE    Average
# 2         1.0         NO  NONE    Average
# 3         1.0         NO  NONE  Very Good
# 4         1.0         NO  NONE    Average
# ...       ...        ...   ...        ...
# 21529     2.0         NO  NONE    Average
# 21530     2.0         NO  NONE    Average
# 21531     2.0         NO  NONE    Average
# 21532     2.0         NO  NONE    Average
# 21533     2.0         NO  NONE    Average
#
# [21021 rows x 10 columns]

# %%
#plt.figure(figsize = (20,20))
sns.heatmap(df1.corr().abs(), annot = True)
# Out:
# <AxesSubplot:>
